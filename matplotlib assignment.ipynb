# %%
"""
Scipy:
We have the min and max temperatures in a city In India for each months of the year.
We would like to find a function to describe this and show it graphically, the dataset
given below.
Task:
1.fitting it to the periodic function
2.plot the fit
Data
Max = 39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25
Min = 21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18
Expected Output:

"""

# %%
import numpy as np
from scipy.optimize import curve_fit
import scipy as sp
#help(sp.optimize)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


plt.style.use(['ggplot'])
plt.subplots(figsize=(8,6))
             
months = np.arange(12)

TMax =np.array([ 39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25])
TMin =np.array([ 21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18])
plt.plot(months,TMax,'ro')
plt.plot(months,TMin,'bo')
plt.xlabel('Months')
plt.ylabel('Min and max temperature')

plt.show()

# %%
import numpy as np
def yeartemp(data,a,b,c):
    return (a + b * np.cos((data + c) * 2 * np.pi / data.max()))

r_max, c_max = sp.optimize.curve_fit(yeartemp, months,TMax, [40, 20, 0])
r_min, c_min = sp.optimize.curve_fit(yeartemp, months,TMin, [-40, 20, 0])

# %%
r_max, c_max
# Out:
# (array([ 39.88861733, -10.59083162,   1.33370157]),
#  array([[ 1.28972691, -0.14357506, -0.02263908],
#         [-0.14357506,  2.57009353, -0.03276298],
#         [-0.02263908, -0.03276298,  0.07074023]]))

# %%
days = np.linspace(0, 12, num=365)

plt.figure(figsize=(8,6))
plt.plot(months, TMax, 'ro')
plt.plot(days, yeartemp(days, *r_max), 'r-')
plt.plot(months, TMin, 'bo')
plt.plot(days, yeartemp(days, *r_min), 'b-')
plt.xlabel('Month')
plt.ylabel('Temperature ($^\circ$C)')

plt.show()

# %%
"""
Matplotlib:
This assignment is for visualization using matplotlib:
data to use:
url=https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv
titanic = pd.read_csv(url)
Charts to plot:
1. Create a pie chart presenting the male/female proportion
2. Create a scatterplot with the Fare paid and the Age, differ the plot color by gender"""
# Out:
# '\nMatplotlib:\nThis assignment is for visualization using matplotlib:\ndata to use:\nurl=https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv\ntitanic = pd.read_csv(url)\nCharts to plot:\n1. Create a pie chart presenting the male/female proportion\n2. Create a scatterplot with the Fare paid and the Age, differ the plot color by gender'

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
url="https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv"
df=pd.read_csv(url)

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
plt.style.use(['ggplot'])
print(df['sex'].value_counts())
import random
df['sex'].value_counts().plot.pie(figsize=(8,6),shadow=True,autopct='%.2f')
plt.show()
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
df.dropna(subset=['sex'],inplace=True)

# %%
import matplotlib.patches as mp
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(8,6))
colors={'male':'red', 'female':'blue'}
ax.scatter(df['age'], df['fare'], c=df['sex'].map(colors),s=100)

red_patch = mp.Patch(color='red', label='male')
blue_patch = mp.Patch(color='blue', label='female')
plt.legend(handles=[red_patch, blue_patch])

plt.show()
